# %% [markdown]
# # Libraries

# %%
from IPython.display import Image, display
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Plots

# %%
# ROC_AIC Plots
path_roc0 = f"roc_plots/roc_df0.png"
path_roc1 = f"roc_plots/roc_df1.png"
path_roc2 = f"roc_plots/roc_df2.png"
path_roc3 = f"roc_plots/roc_df3.png"
path_roc4 = f"roc_plots/roc_df4.png"
path_roc5 = f"roc_plots/roc_df5.png"

# SHAP Plots
path_log0 = f"shap_plots/shap_log_model_df0.png"
path_log1 = f"shap_plots/shap_log_model_df1.png"
path_log2 = f"shap_plots/shap_log_model_df2.png"
path_log3 = f"shap_plots/shap_log_model_df3.png"
path_log4 = f"shap_plots/shap_log_model_df4.png"
path_log5 = f"shap_plots/shap_log_model_df5.png"

path_lda0 = f"shap_plots/shap_lda_model_df0.png"
path_lda1 = f"shap_plots/shap_lda_model_df1.png"
path_lda2 = f"shap_plots/shap_lda_model_df2.png"
path_lda3 = f"shap_plots/shap_lda_model_df3.png"
path_lda4 = f"shap_plots/shap_lda_model_df4.png"
path_lda5 = f"shap_plots/shap_lda_model_df5.png"

path_qda0 = f"shap_plots/shap_qda_model_df0.png"
path_qda1 = f"shap_plots/shap_qda_model_df1.png"
path_qda2 = f"shap_plots/shap_qda_model_df2.png"
path_qda3 = f"shap_plots/shap_qda_model_df3.png"
path_qda4 = f"shap_plots/shap_qda_model_df4.png"
path_qda5 = f"shap_plots/shap_qda_model_df5.png"

path_el0 = f"shap_plots/shap_el_model_df0.png"
path_el1 = f"shap_plots/shap_el_model_df1.png"
path_el2 = f"shap_plots/shap_el_model_df2.png"
path_el3 = f"shap_plots/shap_el_model_df3.png"
path_el4 = f"shap_plots/shap_el_model_df4.png"
path_el5 = f"shap_plots/shap_el_model_df5.png"

path_knn0 = f"shap_plots/shap_knn_model_df0.png"
path_knn1 = f"shap_plots/shap_knn_model_df1.png"
path_knn2 = f"shap_plots/shap_knn_model_df2.png"
path_knn3 = f"shap_plots/shap_knn_model_df3.png"
path_knn4 = f"shap_plots/shap_knn_model_df4.png"
path_knn5 = f"shap_plots/shap_knn_model_df5.png"

path_svc0 = f"shap_plots/shap_svc_model_df0.png"
path_svc1 = f"shap_plots/shap_svc_model_df1.png"
path_svc2 = f"shap_plots/shap_svc_model_df2.png"
path_svc3 = f"shap_plots/shap_svc_model_df3.png"
path_svc4 = f"shap_plots/shap_svc_model_df4.png"
path_svc5 = f"shap_plots/shap_svc_model_df5.png"

path_tr0 = f"shap_plots/shap_tr_model_df0.png"
path_tr1 = f"shap_plots/shap_tr_model_df1.png"
path_tr2 = f"shap_plots/shap_tr_model_df2.png"
path_tr3 = f"shap_plots/shap_tr_model_df3.png"
path_tr4 = f"shap_plots/shap_tr_model_df4.png"
path_tr5 = f"shap_plots/shap_tr_model_df5.png"

path_rf0 = f"shap_plots/shap_rf_model_df0.png"
path_rf1 = f"shap_plots/shap_rf_model_df1.png"
path_rf2 = f"shap_plots/shap_rf_model_df2.png"
path_rf3 = f"shap_plots/shap_rf_model_df3.png"
path_rf4 = f"shap_plots/shap_rf_model_df4.png"
path_rf5 = f"shap_plots/shap_rf_model_df5.png"

path_gb0 = f"shap_plots/shap_gb_model_df0.png"
path_gb1 = f"shap_plots/shap_gb_model_df1.png"
path_gb2 = f"shap_plots/shap_gb_model_df2.png"
path_gb3 = f"shap_plots/shap_gb_model_df3.png"
path_gb4 = f"shap_plots/shap_gb_model_df4.png"
path_gb5 = f"shap_plots/shap_gb_model_df5.png"

path_xgb0 = f"shap_plots/shap_xgb_model_df0.png"
path_xgb1 = f"shap_plots/shap_xgb_model_df1.png"
path_xgb2 = f"shap_plots/shap_xgb_model_df2.png"
path_xgb3 = f"shap_plots/shap_xgb_model_df3.png"
path_xgb4 = f"shap_plots/shap_xgb_model_df4.png"
path_xgb5 = f"shap_plots/shap_xgb_model_df5.png"

# %% [markdown]
# # ROC_AUC + SHAP Plots

# %%
def fun_fig_com(path1, path2, i):
    img1 = mpimg.imread(path1)
    img2 = mpimg.imread(path2)

    fig, axes = plt.subplots(nrows = 2, ncols = 1 , figsize=(20, 10))

    axes[0].imshow(img1)
    axes[0].axis('off')
    # axes[0].set_title(f'ROC_AUC df{i}', fontweight='bold')

    axes[1].imshow(img2)
    axes[1].axis('off')
    # axes[1].set_title(f'SHAP df{i}', fontweight='bold')

    plt.tight_layout()
    plt.show()

# %%
fun_fig_com(path_roc0, path_qda0, 0)
fun_fig_com(path_roc1, path_xgb1, 1)
fun_fig_com(path_roc2, path_xgb2, 2)
fun_fig_com(path_roc3, path_xgb3, 3)
fun_fig_com(path_roc4, path_xgb4, 4)
fun_fig_com(path_roc5, path_xgb5, 5)
