# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from IPython.display import Image, display

# %% [markdown]
# # Load Plots

# %%
# ROC_AIC Plots
roc1 = f"roc_plots/roc_df1.png"
roc2 = f"roc_plots/roc_df2.png"
roc3 = f"roc_plots/roc_df3.png"
roc4 = f"roc_plots/roc_df4.png"

# SHAP Plots
svc_shap1 = f"shap_plots/df1_SVC_shap_plot.png"
svc_shap2 = f"shap_plots/df2_SVC_shap_plot.png"
svc_shap3 = f"shap_plots/df3_SVC_shap_plot.png"
svc_shap4 = f"shap_plots/df4_SVC_shap_plot.png"

rf_shap1 = f"shap_plots/df1_Random_Forest_shap_plot.png"
rf_shap2 = f"shap_plots/df2_Random_Forest_shap_plot.png"
rf_shap3 = f"shap_plots/df3_Random_Forest_shap_plot.png"
rf_shap4 = f"shap_plots/df4_Random_Forest_shap_plot.png"

gb_shap1 = f"shap_plots/df1_GBoost_shap_plot.png"
gb_shap2 = f"shap_plots/df2_GBoost_shap_plot.png"
gb_shap3 = f"shap_plots/df3_GBoost_shap_plot.png"
gb_shap4 = f"shap_plots/df4_GBoost_shap_plot.png"

xgb_shap1 = f"shap_plots/df1_XGBoost_shap_plot.png"
xgb_shap2 = f"shap_plots/df2_XGBoost_shap_plot.png"
xgb_shap3 = f"shap_plots/df3_XGBoost_shap_plot.png"
xgb_shap4 = f"shap_plots/df4_XGBoost_shap_plot.png"

# SHAP Mean Values
svc_values1 = pd.read_pickle(r".\shap_plots\df1_SVC_mean_shap.pkl")
svc_values2 = pd.read_pickle(r".\shap_plots\df2_SVC_mean_shap.pkl")
svc_values3 = pd.read_pickle(r".\shap_plots\df3_SVC_mean_shap.pkl")
svc_values4 = pd.read_pickle(r".\shap_plots\df4_SVC_mean_shap.pkl")

rf_values1 = pd.read_pickle(r".\shap_plots\df1_Random_Forest_mean_shap.pkl")
rf_values2 = pd.read_pickle(r".\shap_plots\df2_Random_Forest_mean_shap.pkl")
rf_values3 = pd.read_pickle(r".\shap_plots\df3_Random_Forest_mean_shap.pkl")
rf_values4 = pd.read_pickle(r".\shap_plots\df4_Random_Forest_mean_shap.pkl")

gb_values1 = pd.read_pickle(r".\shap_plots\df3_XGBoost_mean_shap.pkl")
gb_values2 = pd.read_pickle(r".\shap_plots\df2_XGBoost_mean_shap.pkl")
gb_values3 = pd.read_pickle(r".\shap_plots\df3_XGBoost_mean_shap.pkl")
gb_values4 = pd.read_pickle(r".\shap_plots\df4_XGBoost_mean_shap.pkl")

xgb_values1 = pd.read_pickle(r".\shap_plots\df1_XGBoost_mean_shap.pkl")
xgb_values2 = pd.read_pickle(r".\shap_plots\df2_XGBoost_mean_shap.pkl")
xgb_values3 = pd.read_pickle(r".\shap_plots\df3_XGBoost_mean_shap.pkl")
xgb_values4 = pd.read_pickle(r".\shap_plots\df4_XGBoost_mean_shap.pkl")

# Accuracy, Classification report, MCC
MCC1 = pd.read_pickle(f"./shap_plots/df1_mcc.pkl")
MCC2 = pd.read_pickle(f"./shap_plots/df2_mcc.pkl")
MCC3 = pd.read_pickle(f"./shap_plots/df3_mcc.pkl")
MCC4 = pd.read_pickle(f"./shap_plots/df4_mcc.pkl")

# %%
def fun_fig_com(path1, path2, i):
    img1 = mpimg.imread(path1)
    img2 = mpimg.imread(path2)

    fig, axes = plt.subplots(nrows = 2, ncols = 1 , figsize=(20, 10))

    axes[0].imshow(img1)
    axes[0].axis('off')
    # axes[0].set_title(f'ROC_AUC df{i}', fontweight='bold')

    axes[1].imshow(img2)
    axes[1].axis('off')
    # axes[1].set_title(f'SHAP df{i}', fontweight='bold')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # ROC_AUC + SHAP Plots

# %%
fun_fig_com(roc1, xgb_shap1, 1)
fun_fig_com(roc2, gb_shap2, 2)
fun_fig_com(roc3, xgb_shap3, 3)
fun_fig_com(roc4, xgb_shap4, 4)
